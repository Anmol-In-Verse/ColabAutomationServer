# %%
# 🚀 Google Colab: Full project setup with fixes for model_1

import os
import json

base_dir = "/content/Generative_ai"

structure = {
    "": ["config.json", "env_req.txt", "prompt_api_server.py"],
    "model_1": ["build.json", "prompt_gen.py"],
    "model_1/model": [],
    "model_2": ["build.json", "prompt_gen.py"],
    "model_2/model": []
}

placeholder_content = {...}  # [TRUNCATED FOR BREVITY; to be fully expanded in final output]

# 🛠️ Create files and directories
for path, files in structure.items():
    ...
    
# ✅ Add full Flask API server logic to prompt_api_server.py
api_server_path = "/content/Generative_ai/prompt_api_server.py"
api_server_code = '''...'''

with open(api_server_path, "w") as f:
    f.write(api_server_code)

print("✅ prompt_api_server.py updated with full Flask server code")

# ✅ Install required Python packages
# !pip install flask flask-cors pyngrok llama-cpp-python

import os
import requests
from tqdm import tqdm

def download_model(url, save_path):
    ...
    
# URLs
model_1_url = "https://huggingface.co/TheBloke/MythoMax-L2-13B-GGUF/resolve/main/mythomax-l2-13b.Q4_K_M.gguf"
model_2_url = "https://huggingface.co/TheBloke/openchat-3.5-1210-GGUF/resolve/main/openchat-3.5-1210.Q5_K_S.gguf"

# Download destinations
model_1_path = "Generative_ai/model_1/model/model_ns.gguf"
model_2_path = "Generative_ai/model_2/model/model_s.gguf"

# Run downloads
download_model(model_1_url, model_1_path)
download_model(model_2_url, model_2_path)

# !python3 /content/Generative_ai/prompt_api_server.py
